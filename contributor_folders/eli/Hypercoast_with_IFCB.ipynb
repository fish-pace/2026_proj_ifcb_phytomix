# %% [markdown]
# # **Interactive Map with PACE and insitu data**<br>
# Author:Gulce Kurtay<br>
# ORCID: 0000-0002-5169-6314<br>
# Sources:<br>
# hypercoast, https://hypercoast.org/<br>
# Woods Hole Dashboard, https://ifcb-data.whoi.edu/dashboard <br>
#
# This notebook designed to combine PACE chl-a data (hypercoast) with in-situ flow cytometry group distribution then make an interactive map.<br>
# Classified IFCB data is limited, so make sure to search the database then find a group distribution that matches with your interest.

# %% [markdown]
# STEP 2.2 summarize the information into daily format to match up with PACE data <br>
# STEP 3   Download the PACE data with hypercoast<br>
# STEP 4   interactive map with spatial chl-a and insitu group distribution

# %% [markdown]
# ##STEP 3  Download the PACE data by using Hypercoast package

# %%
#first install the hypercoast
# %pip install "hypercoast[extra]"

# %%
import pandas as pd
import matplotlib.pyplot as plt
from io import BytesIO
import base64
import hypercoast
from hypercoast import Map

# %%
# Now load the data
import pandas as pd
difcb=pd.read_csv("../../data/mvco_2024.csv")
# Convert the cleaned date strings to datetime objects
difcb['date'] = pd.to_datetime(difcb['date'], format='%Y%m%d')
difcb.head()
# Out:
#                               pid  max_value_column  max_value       date  \
# 0  D20240215T150055_IFCB010_00001  nanoplankton_mix     0.7495 2024-02-15
# 1  D20240215T150055_IFCB010_00002             fiber     0.9995 2024-02-15
# 2  D20240215T150055_IFCB010_00003      Rhizosolenia     0.9980 2024-02-15
# 3  D20240215T150055_IFCB010_00004          detritus     1.0000 2024-02-15
# 4  D20240215T150055_IFCB010_00005          detritus     0.9620 2024-02-15
#
#            pid_date                    bin_id  latitude  longitude  \
# 0  D20240215T150055  D20240215T150055_IFCB010    41.325   -70.5667
# 1  D20240215T150055  D20240215T150055_IFCB010    41.325   -70.5667
# 2  D20240215T150055  D20240215T150055_IFCB010    41.325   -70.5667
# 3  D20240215T150055  D20240215T150055_IFCB010    41.325   -70.5667
# 4  D20240215T150055  D20240215T150055_IFCB010    41.325   -70.5667
#
#            bin_date
# 0  D20240215T150055
# 1  D20240215T150055
# 2  D20240215T150055
# 3  D20240215T150055
# 4  D20240215T150055

# %%
import hypercoast

# Step 1: Login to NASA Earthdata
hypercoast.nasa_earth_login()# this will be your username and password for nasa_earth. you can get it easily

# %%
#Search for Chl-a data within a specific temporal range
temporal = ("2024-05-01", "2024-06-21")  # Adjust date range as needed
results = hypercoast.search_pace_chla(temporal=temporal)

# Step 3: Download the Chl-a data thi is the type three processed chl-a data
hypercoast.download_nasa_data(results, "chla")

# Print the search results to see what you found
print(results)
# Out:
# QUEUEING TASKS | :   0%|          | 0/47 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/47 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/47 [00:00<?, ?it/s]
# [Collection: {'ShortName': 'PACE_OCI_L3M_CHL_NRT', 'Version': '2.0'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'SouthBoundingCoordinate': -90, 'WestBoundingCoordinate': -180, 'NorthBoundingCoordinate': 90, 'EastBoundingCoordinate': 180}]}}}
# Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-05-01T00:00:00Z', 'EndingDateTime': '2024-05-01T23:59:59Z'}}
# Size(MB): 2.894341468811035
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240501.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'Version': '2.0', 'ShortName': 'PACE_OCI_L3M_CHL_NRT'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'NorthBoundingCoordinate': 90, 'WestBoundingCoordinate': -180, 'SouthBoundingCoordinate': -90, 'EastBoundingCoordinate': 180}]}}}
# Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-05-02T23:59:59Z', 'BeginningDateTime': '2024-05-02T00:00:00Z'}}
# Size(MB): 2.6580638885498047
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240502.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'Version': '2.0', 'ShortName': 'PACE_OCI_L3M_CHL_NRT'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -180, 'SouthBoundingCoordinate': -90, 'EastBoundingCoordinate': 180, 'NorthBoundingCoordinate': 90}]}}}
# Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-05-03T23:59:59Z', 'BeginningDateTime': '2024-05-03T00:00:00Z'}}
# Size(MB): 2.828129768371582
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240503.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'ShortName': 'PACE_OCI_L3M_CHL_NRT', 'Version': '2.0'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'NorthBoundingCoordinate': 90, 'SouthBoundingCoordinate': -90, 'EastBoundingCoordinate': 180, 'WestBoundingCoordinate': -180}]}}}
# Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-05-04T00:00:00Z', 'EndingDateTime': '2024-05-04T23:59:59Z'}}
# Size(MB): 2.940826416015625
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240504.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'Version': '2.0', 'ShortName': 'PACE_OCI_L3M_CHL_NRT'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'EastBoundingCoordinate': 180, 'NorthBoundingCoordinate': 90, 'WestBoundingCoordinate': -180, 'SouthBoundingCoordinate': -90}]}}}
# Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-05-05T00:00:00Z', 'EndingDateTime': '2024-05-05T23:59:59Z'}}
# Size(MB): 2.985703468322754
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240505.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'ShortName': 'PACE_OCI_L3M_CHL_NRT', 'Version': '2.0'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'SouthBoundingCoordinate': -90, 'NorthBoundingCoordinate': 90, 'EastBoundingCoordinate': 180, 'WestBoundingCoordinate': -180}]}}}
# Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-05-06T23:59:59Z', 'BeginningDateTime': '2024-05-06T00:00:00Z'}}
# Size(MB): 2.987476348876953
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240506.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'ShortName': 'PACE_OCI_L3M_CHL_NRT', 'Version': '2.0'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'SouthBoundingCoordinate': -90, 'NorthBoundingCoordinate': 90, 'EastBoundingCoordinate': 180, 'WestBoundingCoordinate': -180}]}}}
# Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-05-07T00:00:00Z', 'EndingDateTime': '2024-05-07T23:59:59Z'}}
# Size(MB): 2.92580509185791
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240507.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'ShortName': 'PACE_OCI_L3M_CHL_NRT', 'Version': '2.0'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'NorthBoundingCoordinate': 90, 'EastBoundingCoordinate': 180, 'SouthBoundingCoordinate': -90, 'WestBoundingCoordinate': -180}]}}}
# Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-05-08T00:00:00Z', 'EndingDateTime': '2024-05-08T23:59:59Z'}}
# Size(MB): 2.992044448852539
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240508.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'ShortName': 'PACE_OCI_L3M_CHL_NRT', 'Version': '2.0'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'SouthBoundingCoordinate': -90, 'EastBoundingCoordinate': 180, 'NorthBoundingCoordinate': 90, 'WestBoundingCoordinate': -180}]}}}
# Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-05-09T00:00:00Z', 'EndingDateTime': '2024-05-09T23:59:59Z'}}
# Size(MB): 2.9238080978393555
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240509.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'Version': '2.0', 'ShortName': 'PACE_OCI_L3M_CHL_NRT'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -180, 'NorthBoundingCoordinate': 90, 'EastBoundingCoordinate': 180, 'SouthBoundingCoordinate': -90}]}}}
# Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-05-10T23:59:59Z', 'BeginningDateTime': '2024-05-10T00:00:00Z'}}
# Size(MB): 2.939922332763672
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240510.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'Version': '2.0', 'ShortName': 'PACE_OCI_L3M_CHL_NRT'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -180, 'NorthBoundingCoordinate': 90, 'SouthBoundingCoordinate': -90, 'EastBoundingCoordinate': 180}]}}}
# Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-05-11T00:00:00Z', 'EndingDateTime': '2024-05-11T23:59:59Z'}}
# Size(MB): 2.9315271377563477
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240511.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'ShortName': 'PACE_OCI_L3M_CHL_NRT', 'Version': '2.0'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'SouthBoundingCoordinate': -90, 'WestBoundingCoordinate': -180, 'NorthBoundingCoordinate': 90, 'EastBoundingCoordinate': 180}]}}}
# Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-05-12T23:59:59Z', 'BeginningDateTime': '2024-05-12T00:00:00Z'}}
# Size(MB): 2.867176055908203
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240512.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'Version': '2.0', 'ShortName': 'PACE_OCI_L3M_CHL_NRT'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'SouthBoundingCoordinate': -90, 'NorthBoundingCoordinate': 90, 'EastBoundingCoordinate': 180, 'WestBoundingCoordinate': -180}]}}}
# Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-05-13T00:00:00Z', 'EndingDateTime': '2024-05-13T23:59:59Z'}}
# Size(MB): 3.0035533905029297
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240513.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'Version': '2.0', 'ShortName': 'PACE_OCI_L3M_CHL_NRT'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'EastBoundingCoordinate': 180, 'SouthBoundingCoordinate': -90, 'NorthBoundingCoordinate': 90, 'WestBoundingCoordinate': -180}]}}}
# Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-05-14T00:00:00Z', 'EndingDateTime': '2024-05-14T23:59:59Z'}}
# Size(MB): 2.9489641189575195
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240514.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'ShortName': 'PACE_OCI_L3M_CHL_NRT', 'Version': '2.0'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'NorthBoundingCoordinate': 90, 'EastBoundingCoordinate': 180, 'SouthBoundingCoordinate': -90, 'WestBoundingCoordinate': -180}]}}}
# Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-05-15T23:59:59Z', 'BeginningDateTime': '2024-05-15T00:00:00Z'}}
# Size(MB): 3.0068607330322266
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240515.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'ShortName': 'PACE_OCI_L3M_CHL_NRT', 'Version': '2.0'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'NorthBoundingCoordinate': 90, 'WestBoundingCoordinate': -180, 'SouthBoundingCoordinate': -90, 'EastBoundingCoordinate': 180}]}}}
# Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-05-16T00:00:00Z', 'EndingDateTime': '2024-05-16T23:59:59Z'}}
# Size(MB): 3.0133228302001953
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240516.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'ShortName': 'PACE_OCI_L3M_CHL_NRT', 'Version': '2.0'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'NorthBoundingCoordinate': 90, 'EastBoundingCoordinate': 180, 'SouthBoundingCoordinate': -90, 'WestBoundingCoordinate': -180}]}}}
# Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-05-17T23:59:59Z', 'BeginningDateTime': '2024-05-17T00:00:00Z'}}
# Size(MB): 2.926525115966797
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240517.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'Version': '2.0', 'ShortName': 'PACE_OCI_L3M_CHL_NRT'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'EastBoundingCoordinate': 180, 'NorthBoundingCoordinate': 90, 'SouthBoundingCoordinate': -90, 'WestBoundingCoordinate': -180}]}}}
# Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-05-18T00:00:00Z', 'EndingDateTime': '2024-05-18T23:59:59Z'}}
# Size(MB): 2.735043525695801
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240518.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'ShortName': 'PACE_OCI_L3M_CHL_NRT', 'Version': '2.0'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'NorthBoundingCoordinate': 90, 'SouthBoundingCoordinate': -90, 'EastBoundingCoordinate': 180, 'WestBoundingCoordinate': -180}]}}}
# Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-05-19T00:00:00Z', 'EndingDateTime': '2024-05-19T23:59:59Z'}}
# Size(MB): 2.7148332595825195
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240519.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'Version': '2.0', 'ShortName': 'PACE_OCI_L3M_CHL_NRT'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -180, 'EastBoundingCoordinate': 180, 'SouthBoundingCoordinate': -90, 'NorthBoundingCoordinate': 90}]}}}
# Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-05-20T23:59:59Z', 'BeginningDateTime': '2024-05-20T00:00:00Z'}}
# Size(MB): 2.6593809127807617
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240520.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'ShortName': 'PACE_OCI_L3M_CHL_NRT', 'Version': '2.0'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'SouthBoundingCoordinate': -90, 'WestBoundingCoordinate': -180, 'NorthBoundingCoordinate': 90, 'EastBoundingCoordinate': 180}]}}}
# Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-05-21T23:59:59Z', 'BeginningDateTime': '2024-05-21T00:00:00Z'}}
# Size(MB): 2.7891998291015625
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240521.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'Version': '2.0', 'ShortName': 'PACE_OCI_L3M_CHL_NRT'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'NorthBoundingCoordinate': 90, 'WestBoundingCoordinate': -180, 'SouthBoundingCoordinate': -90, 'EastBoundingCoordinate': 180}]}}}
# Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-05-22T23:59:59Z', 'BeginningDateTime': '2024-05-22T00:00:00Z'}}
# Size(MB): 2.837691307067871
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240522.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'Version': '2.0', 'ShortName': 'PACE_OCI_L3M_CHL_NRT'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'NorthBoundingCoordinate': 90, 'WestBoundingCoordinate': -180, 'EastBoundingCoordinate': 180, 'SouthBoundingCoordinate': -90}]}}}
# Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-05-23T00:00:00Z', 'EndingDateTime': '2024-05-23T23:59:59Z'}}
# Size(MB): 2.8471298217773438
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240523.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'ShortName': 'PACE_OCI_L3M_CHL_NRT', 'Version': '2.0'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'EastBoundingCoordinate': 180, 'WestBoundingCoordinate': -180, 'SouthBoundingCoordinate': -90, 'NorthBoundingCoordinate': 90}]}}}
# Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-05-24T00:00:00Z', 'EndingDateTime': '2024-05-24T23:59:59Z'}}
# Size(MB): 2.5405664443969727
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240524.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'ShortName': 'PACE_OCI_L3M_CHL_NRT', 'Version': '2.0'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'EastBoundingCoordinate': 180, 'SouthBoundingCoordinate': -90, 'WestBoundingCoordinate': -180, 'NorthBoundingCoordinate': 90}]}}}
# Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-05-30T00:00:00Z', 'EndingDateTime': '2024-05-30T23:59:59Z'}}
# Size(MB): 1.0206050872802734
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240530.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'ShortName': 'PACE_OCI_L3M_CHL_NRT', 'Version': '2.0'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'NorthBoundingCoordinate': 90, 'EastBoundingCoordinate': 180, 'WestBoundingCoordinate': -180, 'SouthBoundingCoordinate': -90}]}}}
# Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-05-31T23:59:59Z', 'BeginningDateTime': '2024-05-31T00:00:00Z'}}
# Size(MB): 2.8529558181762695
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240531.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'ShortName': 'PACE_OCI_L3M_CHL_NRT', 'Version': '2.0'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'EastBoundingCoordinate': 180, 'SouthBoundingCoordinate': -90, 'WestBoundingCoordinate': -180, 'NorthBoundingCoordinate': 90}]}}}
# Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-06-01T00:00:00Z', 'EndingDateTime': '2024-06-01T23:59:59Z'}}
# Size(MB): 2.7839736938476562
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240601.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'Version': '2.0', 'ShortName': 'PACE_OCI_L3M_CHL_NRT'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -180, 'SouthBoundingCoordinate': -90, 'EastBoundingCoordinate': 180, 'NorthBoundingCoordinate': 90}]}}}
# Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-06-02T00:00:00Z', 'EndingDateTime': '2024-06-02T23:59:59Z'}}
# Size(MB): 2.7200698852539062
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240602.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'Version': '2.0', 'ShortName': 'PACE_OCI_L3M_CHL_NRT'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'SouthBoundingCoordinate': -90, 'WestBoundingCoordinate': -180, 'EastBoundingCoordinate': 180, 'NorthBoundingCoordinate': 90}]}}}
# Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-06-03T23:59:59Z', 'BeginningDateTime': '2024-06-03T00:00:00Z'}}
# Size(MB): 2.331110954284668
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240603.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'Version': '2.0', 'ShortName': 'PACE_OCI_L3M_CHL_NRT'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'SouthBoundingCoordinate': -90, 'WestBoundingCoordinate': -180, 'NorthBoundingCoordinate': 90, 'EastBoundingCoordinate': 180}]}}}
# Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-06-04T23:59:59Z', 'BeginningDateTime': '2024-06-04T00:00:00Z'}}
# Size(MB): 2.72086238861084
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240604.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'ShortName': 'PACE_OCI_L3M_CHL_NRT', 'Version': '2.0'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'SouthBoundingCoordinate': -90, 'NorthBoundingCoordinate': 90, 'EastBoundingCoordinate': 180, 'WestBoundingCoordinate': -180}]}}}
# Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-06-05T00:00:00Z', 'EndingDateTime': '2024-06-05T23:59:59Z'}}
# Size(MB): 2.9137802124023438
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240605.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'Version': '2.0', 'ShortName': 'PACE_OCI_L3M_CHL_NRT'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'NorthBoundingCoordinate': 90, 'SouthBoundingCoordinate': -90, 'WestBoundingCoordinate': -180, 'EastBoundingCoordinate': 180}]}}}
# Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-06-06T00:00:00Z', 'EndingDateTime': '2024-06-06T23:59:59Z'}}
# Size(MB): 2.9576358795166016
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240606.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'ShortName': 'PACE_OCI_L3M_CHL_NRT', 'Version': '2.0'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'EastBoundingCoordinate': 180, 'SouthBoundingCoordinate': -90, 'NorthBoundingCoordinate': 90, 'WestBoundingCoordinate': -180}]}}}
# Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-06-07T23:59:59Z', 'BeginningDateTime': '2024-06-07T00:00:00Z'}}
# Size(MB): 2.9356679916381836
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240607.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'Version': '2.0', 'ShortName': 'PACE_OCI_L3M_CHL_NRT'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -180, 'NorthBoundingCoordinate': 90, 'SouthBoundingCoordinate': -90, 'EastBoundingCoordinate': 180}]}}}
# Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-06-08T23:59:59Z', 'BeginningDateTime': '2024-06-08T00:00:00Z'}}
# Size(MB): 0.682342529296875
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240608.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'ShortName': 'PACE_OCI_L3M_CHL_NRT', 'Version': '2.0'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'SouthBoundingCoordinate': -90, 'NorthBoundingCoordinate': 90, 'WestBoundingCoordinate': -180, 'EastBoundingCoordinate': 180}]}}}
# Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-06-09T23:59:59Z', 'BeginningDateTime': '2024-06-09T00:00:00Z'}}
# Size(MB): 0.5062026977539062
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240609.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'ShortName': 'PACE_OCI_L3M_CHL_NRT', 'Version': '2.0'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -180, 'SouthBoundingCoordinate': -90, 'NorthBoundingCoordinate': 90, 'EastBoundingCoordinate': 180}]}}}
# Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-06-10T23:59:59Z', 'BeginningDateTime': '2024-06-10T00:00:00Z'}}
# Size(MB): 2.729970932006836
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240610.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'ShortName': 'PACE_OCI_L3M_CHL_NRT', 'Version': '2.0'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'SouthBoundingCoordinate': -90, 'NorthBoundingCoordinate': 90, 'WestBoundingCoordinate': -180, 'EastBoundingCoordinate': 180}]}}}
# Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-06-11T00:00:00Z', 'EndingDateTime': '2024-06-11T23:59:59Z'}}
# Size(MB): 2.8021364212036133
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240611.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'ShortName': 'PACE_OCI_L3M_CHL_NRT', 'Version': '2.0'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'NorthBoundingCoordinate': 90, 'SouthBoundingCoordinate': -90, 'WestBoundingCoordinate': -180, 'EastBoundingCoordinate': 180}]}}}
# Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-06-12T00:00:00Z', 'EndingDateTime': '2024-06-12T23:59:59Z'}}
# Size(MB): 2.86264705657959
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240612.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'ShortName': 'PACE_OCI_L3M_CHL_NRT', 'Version': '2.0'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'NorthBoundingCoordinate': 90, 'EastBoundingCoordinate': 180, 'SouthBoundingCoordinate': -90, 'WestBoundingCoordinate': -180}]}}}
# Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-06-13T23:59:59Z', 'BeginningDateTime': '2024-06-13T00:00:00Z'}}
# Size(MB): 2.8639726638793945
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240613.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'ShortName': 'PACE_OCI_L3M_CHL_NRT', 'Version': '2.0'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'EastBoundingCoordinate': 180, 'SouthBoundingCoordinate': -90, 'WestBoundingCoordinate': -180, 'NorthBoundingCoordinate': 90}]}}}
# Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-06-14T23:59:59Z', 'BeginningDateTime': '2024-06-14T00:00:00Z'}}
# Size(MB): 3.053469657897949
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240614.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'ShortName': 'PACE_OCI_L3M_CHL_NRT', 'Version': '2.0'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'SouthBoundingCoordinate': -90, 'NorthBoundingCoordinate': 90, 'WestBoundingCoordinate': -180, 'EastBoundingCoordinate': 180}]}}}
# Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-06-15T00:00:00Z', 'EndingDateTime': '2024-06-15T23:59:59Z'}}
# Size(MB): 3.076960563659668
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240615.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'ShortName': 'PACE_OCI_L3M_CHL_NRT', 'Version': '2.0'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'EastBoundingCoordinate': 180, 'SouthBoundingCoordinate': -90, 'WestBoundingCoordinate': -180, 'NorthBoundingCoordinate': 90}]}}}
# Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-06-16T00:00:00Z', 'EndingDateTime': '2024-06-16T23:59:59Z'}}
# Size(MB): 2.944854736328125
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240616.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'Version': '2.0', 'ShortName': 'PACE_OCI_L3M_CHL_NRT'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -180, 'SouthBoundingCoordinate': -90, 'NorthBoundingCoordinate': 90, 'EastBoundingCoordinate': 180}]}}}
# Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-06-17T00:00:00Z', 'EndingDateTime': '2024-06-17T23:59:59Z'}}
# Size(MB): 2.942190170288086
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240617.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'ShortName': 'PACE_OCI_L3M_CHL_NRT', 'Version': '2.0'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'NorthBoundingCoordinate': 90, 'WestBoundingCoordinate': -180, 'SouthBoundingCoordinate': -90, 'EastBoundingCoordinate': 180}]}}}
# Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-06-18T23:59:59Z', 'BeginningDateTime': '2024-06-18T00:00:00Z'}}
# Size(MB): 2.841463088989258
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240618.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'Version': '2.0', 'ShortName': 'PACE_OCI_L3M_CHL_NRT'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'SouthBoundingCoordinate': -90, 'EastBoundingCoordinate': 180, 'WestBoundingCoordinate': -180, 'NorthBoundingCoordinate': 90}]}}}
# Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-06-19T00:00:00Z', 'EndingDateTime': '2024-06-19T23:59:59Z'}}
# Size(MB): 2.810885429382324
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240619.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'ShortName': 'PACE_OCI_L3M_CHL_NRT', 'Version': '2.0'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': -180, 'EastBoundingCoordinate': 180, 'SouthBoundingCoordinate': -90, 'NorthBoundingCoordinate': 90}]}}}
# Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-06-20T23:59:59Z', 'BeginningDateTime': '2024-06-20T00:00:00Z'}}
# Size(MB): 2.917085647583008
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240620.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc'], Collection: {'Version': '2.0', 'ShortName': 'PACE_OCI_L3M_CHL_NRT'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'EastBoundingCoordinate': 180, 'SouthBoundingCoordinate': -90, 'WestBoundingCoordinate': -180, 'NorthBoundingCoordinate': 90}]}}}
# Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-06-21T23:59:59Z', 'BeginningDateTime': '2024-06-21T00:00:00Z'}}
# Size(MB): 2.8449573516845703
# Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240621.L3m.DAY.CHL.V2_0.chlor_a.0p1deg.NRT.nc']]

# %%
from hypercoast import read_pace_chla, pace_chla_to_image

# Step 4: Read the downloaded data files into an array
files = "chla/*.nc"  # Adjust file path to where your data is saved
array = read_pace_chla(files)

# Step 5: Select data for a specific date range and calculate the average
flow_date = "2024-05-26"#these should meet with the IFCB dashbpard for one day, you can easily select more days to get more coverage 
selected_array = array.sel(date=slice(flow_date))


# Step 6: Convert the averaged array to an image format
single_image = pace_chla_to_image(selected_array)

# %%
#PLOT GROUP DISTRIBUTION WITH HYPERCOAST
import matplotlib.pyplot as plt
from io import BytesIO
import base64
import ipywidgets as widgets
from hypercoast import Map

# Function to create genus plot for a given bin_date and location (with log-transformed Y-axis)
def create_genus_plot(species_data):
    fig, ax = plt.subplots(figsize=(15, 10))
    ax.bar(species_data['genus'], species_data['max_value'])
    ax.set_yscale('log')
    ax.set_title(f"Genus Distribution (Log Scale)", fontsize=20)
    ax.set_xlabel('Genus', fontsize=18)
    ax.set_ylabel('Max Value (log scale)', fontsize=18)
    ax.tick_params(axis='x', labelrotation=90, labelsize=12)

    # Convert the plot to a base64-encoded image
    buf = BytesIO()
    plt.savefig(buf, format='png', bbox_inches='tight')
    plt.close(fig)
    buf.seek(0)
    
    img_base64 = base64.b64encode(buf.read()).decode('utf-8')
    html_img = f'<img src="data:image/png;base64,{img_base64}" style="width:100%;">'
    return html_img

# Group data by latitude, longitude, and bin_date
locations = difcb.groupby(['latitude', 'longitude', 'bin_date'])

# Create the map centered on your stations
m = Map(center=[41.16341, -70.957489], zoom=8)
m.add_basemap("Hybrid")

# Add the averaged Chl-a raster layer to the map
m.add_raster(
    single_image,
    cmap="jet",
    vmin=-1,
    vmax=2,
    layer_name="Chlorophyll a",
    zoom_to_layer=False,
)

# Add genus distribution markers to the map for each unique bin_date and location
for (lat, lon, bin_date), location_data in locations:
    
    # Group data by genus for the specific bin_date and location
    genus_data = location_data.groupby('genus', as_index=False)['max_value'].sum()
    
    # Create genus distribution plot for the bin_date and location
    genus_plot_html = create_genus_plot(genus_data)
    
    # Construct the HTML for the popup
    popup_html = f"<strong>Station Info</strong><br>Location: {lat:.6f}, {lon:.6f}<br>Bin Date: {bin_date}<br>"
    popup_html += "<div>Genus Distribution:</div>"
    
    # Add the genus distribution plot directly
    popup_html += f'<div id="species_img">{genus_plot_html}</div>'
    
    # Create an HTML widget from the string and set the size of the popup
    popup_widget = widgets.HTML(value=popup_html)
    popup_container = widgets.Box([popup_widget], layout=widgets.Layout(width='600px', height='500px'))
    
    # Add the marker to the map
    location = (lat, lon)
    m.add_marker(location=location, popup=popup_container)

# Display the map with Chl-a raster and species markers
m
# Out:
# Map(center=[41.16341, -70.957489], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title',…
