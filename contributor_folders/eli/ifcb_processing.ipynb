# %%
import pandas as pd

# read csv
df = pd.read_csv("../../data/ifcb.csv")

# filter for Cryptophyta and keep selected columns
out = (
    df[df["genus"] == "Cryptophyta"]
    [["genus", "latitude", "longitude", "count", "date"]]
)

# optional: save result
# out.to_csv("cryptophyta_only.csv", index=False)

# %%
out
# Out:
#             genus  latitude  longitude  count        date
# 31    Cryptophyta    41.362   -70.5226  23596  2024-07-01
# 164   Cryptophyta    41.362   -70.5226  26806  2024-07-02
# 297   Cryptophyta    41.362   -70.5226  19011  2024-07-03
# 426   Cryptophyta    41.362   -70.5226  13839  2024-07-04
# 559   Cryptophyta    41.362   -70.5226  21607  2024-07-05
# 692   Cryptophyta    41.362   -70.5226  30371  2024-07-06
# 826   Cryptophyta    41.362   -70.5226  26505  2024-07-07
# 957   Cryptophyta    41.362   -70.5226  26223  2024-07-08
# 1091  Cryptophyta    41.362   -70.5226  27509  2024-07-09
# 1226  Cryptophyta    41.362   -70.5226  22243  2024-07-10
# 1363  Cryptophyta    41.362   -70.5226  21051  2024-07-11
# 1503  Cryptophyta    41.362   -70.5226  25083  2024-07-12
# 1639  Cryptophyta    41.362   -70.5226  19709  2024-07-13
# 1770  Cryptophyta    41.362   -70.5226  27702  2024-07-14
# 1901  Cryptophyta    41.362   -70.5226  28746  2024-07-15
# ...
